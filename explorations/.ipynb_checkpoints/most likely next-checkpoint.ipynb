# %%
import matplotlib.pyplot as plt
import numpy as np
import csv

# %matplotlib inline

# %%
f = open('../data/test.csv', 'r')
csv_reader = csv.DictReader(f)

# %%
rows = [row for row in csv_reader]
sequences = {int(row['Id']): [int(s) for s in row['Sequence'].split(',')] for row in rows}
print(len(sequences.keys()))
# Out:
# 113845

# %% [markdown]
# # Plot Random Sequences

# %%
from random import sample

# %%
def plot_seq(ax, seq):
    colors = ['k', 'b', 'y', 'r']
    filters = [lambda e: e[1] > 1, lambda e: e[1] == 1, lambda e: e[1] == 0, lambda e: e[1] < 0]
    i = range(1, len(seq) + 1)
    pnts = list(zip(i, seq))
    ax.plot(i, seq, color='k')
    for c, f in zip(colors,filters):
        try:
            x, y = zip(*list(filter(f, pnts)))
            ax.scatter(x, y, marker='o', color=c)
        except:
            pass
    ax.axis('off')

# %%
plt.rcParams['figure.figsize'] = (30, 20)

seq_ids = sample(sequences.keys(), 100)
fig, axs = plt.subplots(10, 10)
for ax, sid in zip(axs.ravel(), seq_ids):
    plot_seq(ax, sequences[sid])

# %% [markdown]
# # Monotonicity

# %%
def strictly_increasing(A):
    return all(x < y for x, y in zip(A, A[1:]))
    
def non_decreasing(A):
    return all(x <= y for x, y in zip(A, A[1:]))
    
def strictly_decreasing(A):
    return all(x > y for x, y in zip(A, A[1:]))
    
def non_increasing(A):
    return all(x >= y for x, y in zip(A, A[1:]))

# %%
A0 = filter(strictly_increasing, sequences.values())
A1 = filter(non_decreasing, sequences.values())
A2 = filter(strictly_decreasing, sequences.values())
A3 = filter(non_increasing, sequences.values())

# %% [markdown]
# # Strictly Increasing

# %%
A0_samp = sample(list(A0), 100)
fig, axs = plt.subplots(10, 10)
for ax, A in zip(axs.ravel(), A0_samp):
    plot_seq(ax, A)

# %% [markdown]
# # non-decreasing

# %%
A1_samp = sample(list(A1), 100)
fig, axs = plt.subplots(10, 10)
for ax, A in zip(axs.ravel(), A1_samp):
    plot_seq(ax, A)

# %% [markdown]
# # Strictly decreasing

# %%
A2_samp = sample(list(A2), 100)
fig, axs = plt.subplots(10, 10)
for ax, A in zip(axs.ravel(), A2_samp):
    plot_seq(ax, A)

# %% [markdown]
# # non-increasing

# %%
A3_samp = sample(list(A3), 100)
fig, axs = plt.subplots(10, 10)
for ax, A in zip(axs.ravel(), A3_samp):
    plot_seq(ax, A)

# %% [markdown]
# # non-monotonicity

# %%
def non_monotonic(A):
    return not any([strictly_increasing(A), strictly_decreasing(A), non_increasing(A), non_decreasing(A)])

# %%
A4 = list(filter(non_monotonic, sequences.values()))

# %%
A4_samp = sample(list(A4), 100)
fig, axs = plt.subplots(10, 10)
for ax, A in zip(axs.ravel(), A4_samp):
    plot_seq(ax, A)

# %% [markdown]
# # checking for fits

# %%
A0 = list(filter(strictly_increasing, sequences.values()))
A1 = list(filter(non_decreasing, sequences.values()))
A2 = list(filter(strictly_decreasing, sequences.values()))
A3 = list(filter(non_increasing, sequences.values()))
A4 = list(filter(non_monotonic, sequences.values()))

# %%
from functools import reduce
from operator import mul
def prod(seq):
    return reduce(mul, seq, 1)

# %%
def interpolate(X, Y):
    return lambda x: sum([yj*prod((x - xk)/(xj - xk) for xk in X if xk != xj) for xj,yj in zip(X,Y)])

# %%
def test(seq):
    X = np.linspace(1, len(seq), len(seq))
    Y = seq

    trainX = X[:-1]
    trainY = Y[:-1]
    testX = X[-1]
    testY = Y[-1]
    
    f = interpolate(trainX, trainY)
    
    y_hat = f(testX)
    try:
        y_hat = np.int64(y_hat)
    except:
        return 0
    if y_hat == testY:
        return 1
    return 0

# %%
a = sample(list(sequences.values()),10000)
sum([test(seq) for seq in a])/len(a)
# Out:
# 0.0065

# %%
a = sample(list(A0),1000)
sum([test(seq) for seq in a])/len(a)
# Out:
# 0.014

# %%
a = sample(list(A1),1000)
sum([test(seq) for seq in a])/len(a)
# Out:
# 0.015

# %%
a = list(A2)
sum([test(seq) for seq in a])/len(a)
# Out:
# 0.022058823529411766

# %%
a = list(A3)
sum([test(seq) for seq in a])/len(a)
# Out:
# 0.027777777777777776

# %%
a = sample(list(A4), 1000)
sum([test(seq) for seq in a])/len(a)
# Out:
# 0.001

# %% [markdown]
# # .6% are polynomial

# %%
import scipy.stats as st

# %%
def test(Y):

    trainY = Y[:-1]
    testY = Y[-1]
    
    y_hat = st.mode(trainY).mode[0]
    if y_hat == testY:
        return 1
    return 0

# %%
a = sample(list(sequences.values()),10000)
sum([test(seq) for seq in a])/len(a)
# Out:
# 0.0075

# %%
a = sample(list(A0), 1000)
sum([test(seq) for seq in a])/len(a)
# Out:
# 0.012

# %%
a = sample(list(A1), 1000)
sum([test(seq) for seq in a])/len(a)
# Out:
# 0.012

# %%
a = list(A2)
sum([test(seq) for seq in a])/len(a)
# Out:
# 0.022058823529411766

# %%
a = list(A3)
sum([test(seq) for seq in a])/len(a)
# Out:
# 0.027777777777777776

# %%
a = sample(list(A4),1000)
sum([test(seq) for seq in a])/len(a)
# Out:
# 0.002
